# %%
# !pip install bs4
# !pip install requests
# Out:
# Requirement already satisfied: bs4 in c:\users\panku\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\panku\anaconda3\lib\site-packages (from bs4) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\panku\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.2.1)
# Requirement already satisfied: requests in c:\users\panku\anaconda3\lib\site-packages (2.26.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\panku\anaconda3\lib\site-packages (from requests) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\panku\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\panku\anaconda3\lib\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\panku\anaconda3\lib\site-packages (from requests) (1.26.7)

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# ## Q.1.Ans: A python program to display all the header tags from wikipedia.org

# %%
page= requests.get('https://en.wikipedia.org/wiki/Main_Page')
soup= BeautifulSoup(page.content)

header_tags=['h1','h2','h3','h4','h5','h6','h7']
for i in soup.find_all(header_tags):    
    print(i.name + ' : ' + i.text.strip())
# Out:
# h1 : Main Page
# h1 : Welcome to Wikipedia
# h2 : From today's featured article
# h2 : Did you know ...
# h2 : In the news
# h2 : On this day
# h2 : From today's featured list
# h2 : Today's featured picture
# h2 : Other areas of Wikipedia
# h2 : Wikipedia's sister projects
# h2 : Wikipedia languages
# h2 : Navigation menu
# h3 : Personal tools
# h3 : Namespaces
# h3 : Views
# h3 : Search
# h3 : Navigation
# h3 : Contribute
# h3 : Tools
# h3 : Print/export
# h3 : In other projects
# h3 : Languages

# %% [markdown]
# ## Q.2.Ans: A python program to display IMDB’s Top rated 100 movies’ data

# %%
page1= requests.get('https://www.imdb.com/search/title/?groups=top_100&sort=user_rating,desc&count=100&start=1&ref_=adv_nxt')
soup1= BeautifulSoup(page1.content)

name=[]
for i in soup1.find_all('h3', class_="lister-item-header"):
    cells = i.find_all('a')
    name.append(cells[0].text.strip())
    
rating=[]
for i in soup1.find_all('div', class_="inline-block ratings-imdb-rating"):
    rating.append(i.text.replace('\n',''))
    
release=[]
for i in soup1.find_all('span', class_="lister-item-year text-muted unbold"):
    release.append(i.text)
    
print('*'*73)
print('\t\t\t IMDB’s Top rated 100 Movies')
print('*'*73)
df_movie=pd.DataFrame({'Name of Movie':name, 'Rating of Movie':rating, 'Year of Release of Movie':release})
df_movie
# Out:
# *************************************************************************
# 			 IMDB’s Top rated 100 Movies
# *************************************************************************
#                                     Name of Movie Rating of Movie  \
# 0                        The Shawshank Redemption             9.3
# 1                                   The Godfather             9.2
# 2                                 The Dark Knight             9.0
# 3   The Lord of the Rings: The Return of the King             9.0
# 4                                Schindler's List             9.0
# ..                                            ...             ...
# 95                             North by Northwest             8.3
# 96                                        Vertigo             8.3
# 97                            Singin' in the Rain             8.3
# 98                                   Citizen Kane             8.3
# 99              M - Eine Stadt sucht einen Mörder             8.3
#
#    Year of Release of Movie
# 0                    (1994)
# 1                    (1972)
# 2                    (2008)
# 3                    (2003)
# 4                    (1993)
# ..                      ...
# 95                   (1959)
# 96                   (1958)
# 97                   (1952)
# 98                   (1941)
# 99                   (1931)
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Q.3.Ans: A python program to display IMDB’s Top rated 100 Indian movies’ data

# %%
page2= requests.get('https://www.imdb.com/list/ls009997493/?sort=user_rating,desc&st_dt=&mode=detail&page=1')
soup2= BeautifulSoup(page2.content)

name2=[]
for i in soup2.find_all('h3', class_="lister-item-header"):
    cells = i.find_all('a')
    name2.append(cells[0].text.strip())
    
rating2=[]
for i in soup2.find_all('div', class_="ipl-rating-star small"):
    rating2.append(i.text.replace('\n',''))

release2=[]
for i in soup2.find_all('span', class_="lister-item-year text-muted unbold"):
    release2.append(i.text)
    
print('*'*65)
print('\t\t IMDB’s Top rated 100 Indian Movies')
print('*'*65)
df_movies=pd.DataFrame({'Name of Movie':name2, 'Rating of Movie':rating2, 'Year of Release of Movie':release2})
df_movies
# Out:
# *****************************************************************
# 		 IMDB’s Top rated 100 Indian Movies
# *****************************************************************
#               Name of Movie Rating of Movie Year of Release of Movie
# 0                   Golmaal             8.5                   (1979)
# 1                  3 Idiots             8.4                   (2009)
# 2              Black Friday             8.4                   (2004)
# 3                    Masoom             8.4                   (1983)
# 4                     Guide             8.4                   (1965)
# ..                      ...             ...                      ...
# 95  Jaane Tu... Ya Jaane Na             7.4                   (2008)
# 96                 Rangeela             7.4                   (1995)
# 97   Qayamat Se Qayamat Tak             7.4                   (1988)
# 98             Socha Na Tha             7.4                   (2005)
# 99                    Gunda             7.3                   (1998)
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Q.4.Ans: A python program to display list of respected former presidents of India

# %%
page3= requests.get('https://presidentofindia.nic.in/former-presidents.htm')
soup3= BeautifulSoup(page3.content)

President_name=[]
for i in soup3.find_all('div', class_="presidentListing"):
    cells = i.find_all('h3')
    President_name.append(cells[0].text.strip())

Term=[]
for i in soup3.find_all('div', class_="presidentListing"):
    cells = i.find_all('p')
    Term.append(cells[0].text.strip().replace('Term of Office:',''))

print('-'*68)
print('\t\t\t Former Presidents List')
print('-'*68)

df_president=pd.DataFrame({'Name of President':President_name,'Term of Office':Term})
df_president
# Out:
# --------------------------------------------------------------------
# 			 Former Presidents List
# --------------------------------------------------------------------
#                               Name of President  \
# 0           Shri Ram Nath Kovind (birth - 1945)
# 1             Shri Pranab Mukherjee (1935-2020)
# 2   Smt Pratibha Devisingh Patil (birth - 1934)
# 3            DR. A.P.J. Abdul Kalam (1931-2015)
# 4            Shri K. R. Narayanan (1920 - 2005)
# 5           Dr Shankar Dayal Sharma (1918-1999)
# 6               Shri R Venkataraman (1910-2009)
# 7                  Giani Zail Singh (1916-1994)
# 8         Shri Neelam Sanjiva Reddy (1913-1996)
# 9          Dr. Fakhruddin Ali Ahmed (1905-1977)
# 10     Shri Varahagiri Venkata Giri (1894-1980)
# 11                 Dr. Zakir Husain (1897-1969)
# 12     Dr. Sarvepalli Radhakrishnan (1888-1975)
# 13              Dr. Rajendra Prasad (1884-1963)
#
#                                        Term of Office
# 0                      25 July, 2017 to 25 July, 2022
# 1                      25 July, 2012 to 25 July, 2017
# 2                      25 July, 2007 to 25 July, 2012
# 3                      25 July, 2002 to 25 July, 2007
# 4                      25 July, 1997 to 25 July, 2002
# 5                      25 July, 1992 to 25 July, 1997
# 6                      25 July, 1987 to 25 July, 1992
# 7                      25 July, 1982 to 25 July, 1987
# 8                      25 July, 1977 to 25 July, 1982
# 9                24 August, 1974 to 11 February, 1977
# 10   3 May, 1969 to 20 July, 1969 and 24 August, 1...
# 11                        13 May, 1967 to 3 May, 1969
# 12                       13 May, 1962 to 13 May, 1967
# 13                   26 January, 1950 to 13 May, 1962

# %% [markdown]
# # Q.5.Ans: A python program to scrape cricket rankings

# %% [markdown]
# ### a) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating

# %%
page4= requests.get('https://www.icc-cricket.com/rankings/mens/team-rankings/odi')
soup4= BeautifulSoup(page4.content)

Team=[]
Matches=[]
Points=[]
Rating=[]
Ranking=[]
for i in soup4.find_all('tr')[:11]:
    cells = i.find_all('td')
    if len(cells) == 5:
        Ranking.append(cells[0].text.strip())
        Team.append(cells[1].text.strip().replace('\n'," , "))
        Matches.append(cells[2].text.strip())
        Points.append(cells[3].text.strip())
        Rating.append(cells[4].text.strip())
        
print('-'*50)
print("\t Top 10 ODI Teams in Men's Cricket")
print('-'*50)

df_team = pd.DataFrame({'Ranking':Ranking,'Team':Team,'Matches':Matches,'Points':Points,'Rating':Rating})  
df_team
# Out:
# --------------------------------------------------
# 	 Top 10 ODI Teams in Men's Cricket
# --------------------------------------------------
#   Ranking               Team Matches Points Rating
# 0       1   New Zealand , NZ      16  2,051    128
# 1       2      England , ENG      27  3,226    119
# 2       3        India , IND      28  3,085    110
# 3       4     Pakistan , PAK      19  2,005    106
# 4       5    Australia , AUS      23  2,325    101
# 5       6  South Africa , SA      21  2,111    101
# 6       7   Bangladesh , BAN      27  2,639     98
# 7       8     Sri Lanka , SL      29  2,658     92
# 8       9   West Indies , WI      38  2,621     69
# 9      10  Afghanistan , AFG      18  1,238     69

# %% [markdown]
# ### b) Top 10 ODI Batsmen along with the records of their team and rating.

# %%
page4_b= requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting')
soup4_b= BeautifulSoup(page4_b.content)

Player=[]
Team=[]
Rating=[]

for i in soup4_b.find_all('tr')[:11]:
    cells = i.find_all('td')
    if len(cells) == 5:
        Player.append(cells[1].text.strip().replace('\n'," , "))
        Team.append(cells[2].text.strip())
        Rating.append(cells[3].text.strip())
        
print('-'*40)
print(" Top 10 ODI Batsmen in Men's Cricket")
print('-'*40)

df_batting= pd.DataFrame({'Player':Player,'Team':Team,'Rating':Rating})  
df_batting
# Out:
# ----------------------------------------
#  Top 10 ODI Batsmen in Men's Cricket
# ----------------------------------------
#                   Player Team Rating
# 0             Babar Azam  PAK    892
# 1            Imam-ul-Haq  PAK    815
# 2  Rassie van der Dussen   SA    789
# 3        Quinton de Kock   SA    784
# 4            Virat Kohli  IND    767
# 5           Rohit Sharma  IND    763
# 6            Ross Taylor   NZ    744
# 7           David Warner  AUS    737
# 8         Jonny Bairstow  ENG    732
# 9            Aaron Finch  AUS    715

# %% [markdown]
# ### c) Top 10 ODI bowlers along with the records of their team and rating.

# %%
page4_c= requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling')
print(page4,'\n')
soup4_c= BeautifulSoup(page4_c.content)

Player=[]
Team=[]
Rating=[]

for i in soup4_c.find_all ('tr')[:11]:
    cells = i.find_all('td')
    if len(cells) == 5:
        Player.append(cells[1].text.strip().replace('\n'," , "))
        Team.append(cells[2].text.strip())
        Rating.append(cells[3].text.strip())

print('-'*40)
print("  Top 10 ODI Bowlers in Men's Cricket")
print('-'*40)

df_bowling=pd.DataFrame({'Player':Player,'Team':Team,'Rating':Rating})
df_bowling
# Out:
# <Response [200]>
#
# ----------------------------------------
#   Top 10 ODI Bowlers in Men's Cricket
# ----------------------------------------
#              Player Team Rating
# 0       Trent Boult   NZ    697
# 1    Jasprit Bumrah  IND    682
# 2    Shaheen Afridi  PAK    681
# 3    Josh Hazlewood  AUS    679
# 4  Mujeeb Ur Rahman  AFG    676
# 5      Mehedi Hasan  BAN    672
# 6        Matt Henry   NZ    663
# 7     Mohammad Nabi  AFG    657
# 8       Rashid Khan  AFG    651
# 9      Chris Woakes  ENG    640

# %% [markdown]
# # Q.6.Ans: A python program to display list of respected former president

# %% [markdown]
# ### a) Top 10 ODI teams in women’s cricket along with the records for matches, points and rating

# %%
page5= requests.get('https://www.icc-cricket.com/rankings/womens/team-rankings/odi')
soup5= BeautifulSoup(page5.content)

Team=[]
Matches=[]
Points=[]
Rating=[]
Ranking=[]
for i in soup5.find_all('tr')[:11]:
    cells = i.find_all('td')
    if len(cells) == 5:
        Ranking.append(cells[0].text.strip())
        Team.append(cells[1].text.strip().replace('\n'," , "))
        Matches.append(cells[2].text.strip())
        Points.append(cells[3].text.strip())
        Rating.append(cells[4].text.strip())

print('-'*45)
print("     Top 10 ODI Teams in Women's Cricket")
print('-'*45)

df_team1 = pd.DataFrame({' Ranking':Ranking,'Team':Team,'Matches':Matches,'Points':Points,'Rating':Rating})  
df_team1
# Out:
# ---------------------------------------------
#      Top 10 ODI Teams in Women's Cricket
# ---------------------------------------------
#    Ranking               Team Matches Points Rating
# 0        1    Australia , AUS      29  4,837    167
# 1        2      England , ENG      33  4,046    123
# 2        3  South Africa , SA      35  4,157    119
# 3        4        India , IND      32  3,219    101
# 4        5   New Zealand , NZ      31  3,019     97
# 5        6   West Indies , WI      30  2,768     92
# 6        7   Bangladesh , BAN      12    930     78
# 7        8     Pakistan , PAK      30  1,962     65
# 8        9     Sri Lanka , SL      11    495     45
# 9       10      Ireland , IRE       8    351     44

# %% [markdown]
# ### b) Top 10 women’s ODI Batting players along with the records of their team and rating

# %%
page5_b= requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting')
print(page5_b,'\n')
soup5_b= BeautifulSoup(page5_b.content)

Player=[]
Team=[]
Rating=[]

for i in soup5_b.find_all('tr')[:11]:
    cells = i.find_all('td')
    if len(cells) == 5:
        Player.append(cells[1].text.strip().replace('\n'," , "))
        Team.append(cells[2].text.strip())
        Rating.append(cells[3].text.strip())
        
print('-'*50)
print("  Top 10 ODI Batting Players in Women's Cricket")
print('-'*50)

df_batting1= pd.DataFrame({'Player':Player,'Team':Team,'Rating':Rating})  
df_batting1
# Out:
# <Response [200]>
#
# --------------------------------------------------
#   Top 10 ODI Batting Players in Women's Cricket
# --------------------------------------------------
#                 Player Team Rating
# 0         Alyssa Healy  AUS    785
# 1          Beth Mooney  AUS    749
# 2       Natalie Sciver  ENG    747
# 3      Laura Wolvaardt   SA    732
# 4          Meg Lanning  AUS    710
# 5       Rachael Haynes  AUS    701
# 6    Amy Satterthwaite   NZ    681
# 7       Tammy Beaumont  ENG    667
# 8  Chamari Athapaththu   SL    655
# 9      Smriti Mandhana  IND    649

# %% [markdown]
# ### c) Top 10 women’s ODI all-rounder along with the records of their team and rating

# %%
page5_c= requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder')
print(page5_c,'\n')
soup5_c= BeautifulSoup(page5_c.content)

Player=[]
Team=[]
Rating=[]

for i in soup5_c.find_all('tr')[:11]:
    cells = i.find_all('td')
    if len(cells) == 5:
        Player.append(cells[1].text.strip().replace('\n'," , "))
        Team.append(cells[2].text.strip())
        Rating.append(cells[3].text.strip())
        
print('-'*50)
print("Top 10 women’s ODI all-rounder in Women's Cricket")
print('-'*50)


df_All_Rounder= pd.DataFrame({'Player':Player,'Team':Team,'Rating':Rating})  
df_All_Rounder
# Out:
# <Response [200]>
#
# --------------------------------------------------
# Top 10 women’s ODI all-rounder in Women's Cricket
# --------------------------------------------------
#              Player Team Rating
# 0    Natalie Sciver  ENG    379
# 1      Ellyse Perry  AUS    374
# 2    Marizanne Kapp   SA    349
# 3   Hayley Matthews   WI    339
# 4       Amelia Kerr   NZ    336
# 5  Ashleigh Gardner  AUS    270
# 6     Deepti Sharma  IND    252
# 7     Jess Jonassen  AUS    246
# 8   Katherine Brunt  ENG    220
# 9   Stafanie Taylor   WI    207

# %% [markdown]
# ## Q.7.Ans: A python program to scrape mentioned news details

# %%
page7= requests.get('https://www.cnbc.com/world/?region=world')
soup7= BeautifulSoup(page7.content)

headline=[]
for i in soup7.find_all('a', class_="LatestNews-headline"):
    headline.append(i.get('title'))

time=[]
for i in soup7.find_all('span', class_="LatestNews-wrapper"):
    time.append(i.text)

News_Link = []
for i in soup7.findAll('a',class_="LatestNews-headline"):
    News_Link.append(i.get('href'))
    
print('-'*90)
print('\t\t\t\t\t News Details')
print('-'*90)

News=pd.DataFrame({'Headline': headline, 'Time': time,'News Link': News_Link})
News
# Out:
# ------------------------------------------------------------------------------------------
# 					 News Details
# ------------------------------------------------------------------------------------------
#                                              Headline            Time  \
# 0   JPMorgan downgrades shares of Carvana, cites r...      32 Min Ago
# 1   UN chief calls latest Russian attack on nuclea...      1 Hour Ago
# 2   U.S. Treasury yields fall as investors weigh F...      1 Hour Ago
# 3   SoftBank posts a $21.6 billion quarterly loss ...     4 Hours Ago
# 4   European stocks climb as traders assess earnin...     4 Hours Ago
# 5   Hong Kong cuts hotel quarantine for travelers ...     7 Hours Ago
# 6   Baidu's robotaxis don't need any human staff i...     8 Hours Ago
# 7   Cramer: The Inflation Reduction Act is really ...     9 Hours Ago
# 8   Wall Street likes growth stocks again. Here ar...    10 Hours Ago
# 9   BlackRock: The era of steady growth has ended,...    10 Hours Ago
# 10  Video game giants had a miserable second quart...    10 Hours Ago
# 11  Tech stocks drag Hong Kong's Hang Seng lower; ...    11 Hours Ago
# 12  Celsius withdraws motion to hire CFO back at $...    11 Hours Ago
# 13  Potential curb on Australian LNG exports is an...    11 Hours Ago
# 14  Stock futures rise following S&P 500's third w...    12 Hours Ago
# 15  Climate groups react to Senate passing the Inf...    14 Hours Ago
# 16  The best and worst places to live in the world...    18 Hours Ago
# 17  George Clooney had tequila, Ryan Reynolds gin....    20 Hours Ago
# 18  9 corporate leaders share their best hacks for...    20 Hours Ago
# 19  Bethenny Frankel: The most successful people h...    21 Hours Ago
# 20      The 7 states with the least credit card debt     22 Hours Ago
# 21  Albemarle beats estimates on lithium prices, C...    22 Hours Ago
# 22  These stocks are best positioned to weather a ...    22 Hours Ago
# 23  Strong returns are hard to find in 2022. Three...    22 Hours Ago
# 24  Some consumers are cutting back on restaurant ...    22 Hours Ago
# 25  Climate change is making some homes to costly ...    22 Hours Ago
# 26  Why creating a horror movie haven on Netflix m...    23 Hours Ago
# 27  Elon Musk challenges Twitter CEO Parag Agrawal...  August 6, 2022
# 28  Large Indiana employers Eli Lilly and Cummins ...  August 6, 2022
# 29  Czech prince raises $300,000 in NFTs to restor...  August 6, 2022
#
#                                             News Link
# 0   https://www.cnbc.com/2022/08/08/jpmorgan-downg...
# 1   https://www.cnbc.com/2022/08/08/russia-ukraine...
# 2   https://www.cnbc.com/2022/08/08/us-bonds-treas...
# 3   https://www.cnbc.com/2022/08/08/softbank-visio...
# 4   https://www.cnbc.com/2022/08/08/europe-markets...
# 5   https://www.cnbc.com/2022/08/08/hong-kong-redu...
# 6   https://www.cnbc.com/2022/08/08/baidus-robotax...
# 7   https://www.cnbc.com/2022/08/07/cramer-the-inf...
# 8   https://www.cnbc.com/2022/08/08/wall-street-ba...
# 9   https://www.cnbc.com/2022/08/08/blackrock-era-...
# 10  https://www.cnbc.com/2022/08/08/microsoft-xbox...
# 11  https://www.cnbc.com/2022/08/08/asia-markets-c...
# 12  https://www.cnbc.com/2022/08/07/celsius-withdr...
# 13  https://www.cnbc.com/2022/08/07/potential-curb...
# 14  https://www.cnbc.com/2022/08/07/stock-market-n...
# 15  https://www.cnbc.com/2022/08/07/climate-groups...
# 16  https://www.cnbc.com/2022/08/07/global-liveabi...
# 17  https://www.cnbc.com/2022/08/07/george-clooney...
# 18  https://www.cnbc.com/2022/08/07/9-busy-people-...
# 19  https://www.cnbc.com/2022/08/07/bethenny-frank...
# 20  https://www.cnbc.com/2022/08/07/states-with-th...
# 21  https://www.cnbc.com/2022/08/07/lithium-is-key...
# 22  https://www.cnbc.com/2022/08/07/these-stocks-a...
# 23  https://www.cnbc.com/2022/08/07/strong-returns...
# 24  https://www.cnbc.com/2022/08/07/consumers-are-...
# 25  https://www.cnbc.com/2022/08/07/climate-change...
# 26  https://www.cnbc.com/2022/08/07/netflix-may-be...
# 27  https://www.cnbc.com/2022/08/06/elon-musk-chal...
# 28  https://www.cnbc.com/2022/08/06/eli-lilly-says...
# 29  https://www.cnbc.com/2022/08/06/27-year-old-bo...

# %% [markdown]
# ## Q.8.Ans: A python program to scrape the details of most downloaded articles from AI in last 90 days.

# %%
page8= requests.get('https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles')
soup8= BeautifulSoup(page8.content)

Paper_Title=[]
for i in soup8.find_all('h2', class_="sc-1qrq3sd-1 MKjKb sc-1nmom32-0 sc-1nmom32-1 hqhUYH ebTA-dR"):
    Paper_Title.append(i.text)

Authors=[]
for i in soup8.find_all('span', class_="sc-1w3fpd7-0 pgLAT"):
    Authors.append(i.text)  

Published_Date=[]
for i in soup8.find_all('span', class_="sc-1thf9ly-2 bKddwo"):
    Published_Date.append(i.text)  

Paper_URL=[]
for i in soup8.find_all('a', class_="sc-5smygv-0 nrDZj"):
    Paper_URL.append(i.get('href'))

print('-'*127)
print('\t\t\t\t\t\t Most Downloaded Articles')
print('-'*127)

Articles=pd.DataFrame({'Paper Title': Paper_Title,'Authors': Authors,'Published Date': Published_Date, 'Paper URL':Paper_URL})
Articles
# Out:
# -------------------------------------------------------------------------------------------------------------------------------
# 						 Most Downloaded Articles
# -------------------------------------------------------------------------------------------------------------------------------
#                                           Paper Title  \
# 0                                    Reward is enough
# 1                           Making sense of raw input
# 2   Law and logic: A review from an argumentation ...
# 3              Creativity and artificial intelligence
# 4   Artificial cognition for social human–robot in...
# 5   Explanation in artificial intelligence: Insigh...
# 6                       Making sense of sensory input
# 7   Conflict-based search for optimal multi-agent ...
# 8   Between MDPs and semi-MDPs: A framework for te...
# 9   The Hanabi challenge: A new frontier for AI re...
# 10  Evaluating XAI: A comparison of rule-based and...
# 11           Argumentation in artificial intelligence
# 12  Algorithms for computing strategies in two-pla...
# 13      Multiple object tracking: A literature review
# 14  Selection of relevant features and examples in...
# 15  A survey of inverse reinforcement learning: Ch...
# 16  Explaining individual predictions when feature...
# 17  A review of possible effects of cognitive bias...
# 18  Integrating social power into the decision-mak...
# 19  “That's (not) the output I expected!” On the r...
# 20  Explaining black-box classifiers using post-ho...
# 21  Algorithm runtime prediction: Methods & evalua...
# 22              Wrappers for feature subset selection
# 23  Commonsense visual sensemaking for autonomous ...
# 24         Quantum computation, quantum theory and AI
#
#                                               Authors  Published Date  \
# 0   Silver, David, Singh, Satinder, Precup, Doina,...    October 2021
# 1           Evans, Richard, Bošnjak, Matko and 5 more    October 2021
# 2                   Prakken, Henry, Sartor, Giovanni     October 2015
# 3                                 Boden, Margaret A.      August 1998
# 4     Lemaignan, Séverin, Warnier, Mathieu and 3 more       June 2017
# 5                                        Miller, Tim    February 2019
# 6   Evans, Richard, Hernández-Orallo, José and 3 more      April 2021
# 7   Sharon, Guni, Stern, Roni, Felner, Ariel, Stur...   February 2015
# 8   Sutton, Richard S., Precup, Doina, Singh, Sati...     August 1999
# 9         Bard, Nolan, Foerster, Jakob N. and 13 more      March 2020
# 10  van der Waa, Jasper, Nieuwburg, Elisabeth, Cre...   February 2021
# 11               Bench-Capon, T.J.M., Dunne, Paul E.     October 2007
# 12       Bošanský, Branislav, Lisý, Viliam and 3 more     August 2016
# 13             Luo, Wenhan, Xing, Junliang and 4 more      April 2021
# 14                      Blum, Avrim L., Langley, Pat    December 1997
# 15                   Arora, Saurabh, Doshi, Prashant      August 2021
# 16      Aas, Kjersti, Jullum, Martin, Løland, Anders   September 2021
# 17  Kliegr, Tomáš, Bahník, Štěpán, Fürnkranz, Joha...       June 2021
# 18    Pereira, Gonçalo, Prada, Rui, Santos, Pedro A.    December 2016
# 19                      Riveiro, Maria, Thill, Serge   September 2021
# 20  Kenny, Eoin M., Ford, Courtney, Quinn, Molly, ...        May 2021
# 21  Hutter, Frank, Xu, Lin, Hoos, Holger H., Leyto...    January 2014
# 22                      Kohavi, Ron, John, George H.    December 1997
# 23  Suchan, Jakob, Bhatt, Mehul, Varadarajan, Srik...    October 2021
# 24                                   Ying, Mingsheng    February 2010
#
#                                             Paper URL
# 0   https://www.sciencedirect.com/science/article/...
# 1   https://www.sciencedirect.com/science/article/...
# 2   https://www.sciencedirect.com/science/article/...
# 3   https://www.sciencedirect.com/science/article/...
# 4   https://www.sciencedirect.com/science/article/...
# 5   https://www.sciencedirect.com/science/article/...
# 6   https://www.sciencedirect.com/science/article/...
# 7   https://www.sciencedirect.com/science/article/...
# 8   https://www.sciencedirect.com/science/article/...
# 9   https://www.sciencedirect.com/science/article/...
# 10  https://www.sciencedirect.com/science/article/...
# 11  https://www.sciencedirect.com/science/article/...
# 12  https://www.sciencedirect.com/science/article/...
# 13  https://www.sciencedirect.com/science/article/...
# 14  https://www.sciencedirect.com/science/article/...
# 15  https://www.sciencedirect.com/science/article/...
# 16  https://www.sciencedirect.com/science/article/...
# 17  https://www.sciencedirect.com/science/article/...
# 18  https://www.sciencedirect.com/science/article/...
# 19  https://www.sciencedirect.com/science/article/...
# 20  https://www.sciencedirect.com/science/article/...
# 21  https://www.sciencedirect.com/science/article/...
# 22  https://www.sciencedirect.com/science/article/...
# 23  https://www.sciencedirect.com/science/article/...
# 24  https://www.sciencedirect.com/science/article/...

# %% [markdown]
# ## Q.9.Ans: A python program to scrape details from dineout.co.in

# %%
page9= requests.get('https://www.dineout.co.in/delhi-restaurants/buffet-special')
soup9= BeautifulSoup(page9.content)

restaurant_name= []
for i in soup9.find_all('a', class_="restnt-name ellipsis"):
    restaurant_name.append(i.text)

Cuisine=[]
for i in soup9.find_all('div', class_="detail-info"):
    Cuisine.append((i.text.split()[6])+(' ')+(i.text.split()[7]))


location=[]
for i in soup9.find_all('div', class_="restnt-loc ellipsis"):
    location.append(i.text)

Ratings= []
for i in soup9.find_all('div', class_="restnt-rating rating-4"):
    Ratings.append(i.text)

Image_URL= []
for i in soup9.find_all('img', class_="no-img"):
    Image_URL.append(i['data-src'])


print('-'*127)
print('\t\t\t\t\t\t Restaurant Details')
print('-'*127)

dineout=pd.DataFrame({'Restaurant_Name':restaurant_name,'Cuisine':Cuisine,'Location':location,'Ratings':Ratings,'Image_URL':Image_URL})
dineout
# Out:
# -------------------------------------------------------------------------------------------------------------------------------
# 						 Restaurant Details
# -------------------------------------------------------------------------------------------------------------------------------
#                     Restaurant_Name               Cuisine  \
# 0                   Castle Barbeque        Chinese, North
# 1                   Jungle Jamboree         North Indian,
# 2                        Cafe Knosh  Italian, Continental
# 3                   Castle Barbeque        Chinese, North
# 4              The Barbeque Company         North Indian,
# 5                       India Grill         North Indian,
# 6                    Delhi Barbeque          North Indian
# 7  The Monarch - Bar Be Que Village          North Indian
# 8                 Indian Grill Room         North Indian,
#
#                                             Location Ratings  \
# 0                     Connaught Place, Central Delhi     4.1
# 1             3CS Mall,Lajpat Nagar - 3, South Delhi     3.9
# 2  The Leela Ambience Convention Hotel,Shahdara, ...     4.3
# 3             Pacific Mall,Tagore Garden, West Delhi     3.9
# 4                 Gardens Galleria,Sector 38A, Noida       4
# 5               Hilton Garden Inn,Saket, South Delhi     3.9
# 6     Taurus Sarovar Portico,Mahipalpur, South Delhi     3.7
# 7  Indirapuram Habitat Centre,Indirapuram, Ghaziabad     3.8
# 8   Suncity Business Tower,Golf Course Road, Gurgaon     4.3
#
#                                            Image_URL
# 0  https://im1.dineout.co.in/images/uploads/resta...
# 1  https://im1.dineout.co.in/images/uploads/resta...
# 2  https://im1.dineout.co.in/images/uploads/resta...
# 3  https://im1.dineout.co.in/images/uploads/resta...
# 4  https://im1.dineout.co.in/images/uploads/resta...
# 5  https://im1.dineout.co.in/images/uploads/resta...
# 6  https://im1.dineout.co.in/images/uploads/resta...
# 7  https://im1.dineout.co.in/images/uploads/resta...
# 8  https://im1.dineout.co.in/images/uploads/resta...

# %% [markdown]
# ## Q.10.Ans: A python program to scrape the details of top publications from Google Scholar

# %%
page10= requests.get('https://scholar.google.com/citations?view_op=top_venues&hl=en')
soup10= BeautifulSoup(page10.content)

Rank=[]
for i in soup10.find_all('td', class_="gsc_mvt_p"):
    Rank.append(i.text)

publication=[]
for i in soup10.find_all('td', class_="gsc_mvt_t"):
    publication.append(i.text)

h5_index=[]
for i in soup10.find_all('a', class_="gs_ibl gsc_mp_anchor"):
    h5_index.append(i.text)

h5_media=[] 
for i in soup10.find_all('span', class_="gs_ibl gsc_mp_anchor"):
    h5_media.append(i.text)

print('-'*65)
print('\tThe Details of Top Publications from Google Scholar')
print('-'*65)
    
publications=pd.DataFrame({'Rank':Rank,'Publication':publication,'h5_index':h5_index, 'h5_media':h5_media})
publications
# Out:
# -----------------------------------------------------------------
# 	The Details of Top Publications from Google Scholar
# -----------------------------------------------------------------
#     Rank                                        Publication h5_index h5_media
# 0     1.                                             Nature      444      667
# 1     2.                The New England Journal of Medicine      432      780
# 2     3.                                            Science      401      614
# 3     4.  IEEE/CVF Conference on Computer Vision and Pat...      389      627
# 4     5.                                         The Lancet      354      635
# ..   ...                                                ...      ...      ...
# 95   96.                       Journal of Business Research      145      233
# 96   97.                                   Molecular Cancer      145      209
# 97   98.                                            Sensors      145      201
# 98   99.                              Nature Climate Change      144      228
# 99  100.                    IEEE Internet of Things Journal      144      212
#
# [100 rows x 4 columns]
